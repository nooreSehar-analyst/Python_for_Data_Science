# %% [markdown]
# Variables in Financial Context

# %%
# task 1: portfolio identification
client_name = "ali"
account_id = 256-4928
preferred_sector = 'energy'
initial_deposit = 2567.000
print(client_name)
print(initial_deposit)
# Out:
# ali
# 2567.0

# %%
# task 2: variable re-assignment
stock_price = 150
stock_price = 155
print(stock_price)
# Out:
# 155

# %%
# the swapping trick
open_price = 100
close_price = 120
open_price, close_price = close_price, open_price
print(open_price)
print(close_price)
# Out:
# 120
# 100

# %%
# question 2 descriptive naming
annual_net_profit_margin = 50000000
total_gold_medal_count = 12
stock_high_price_of_52_week =150
print(stock_high_price_of_52_week)
# Out:
# 150

# %%
#question 3: type awareness
input_data = "500"
print(type(input_data))
# Out:
# <class 'str'>

# %%
clean_data = int(input_data)
print(type(clean_data))
# Out:
# <class 'int'>
